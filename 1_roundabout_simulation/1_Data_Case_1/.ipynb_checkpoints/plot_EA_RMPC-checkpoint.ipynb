# %%
import numpy as np
import random as random
import math
import time
import matplotlib.pyplot as plt
from matplotlib import colors
from scipy.io import savemat
from shapely.geometry import Polygon, Point

from Check_Safety import Check_Safety

# %%
# %matplotlib inline

# %%
def rota_rect(box, theta, x, y):

    box_matrix = np.array(box) - np.repeat(np.array([[x, y]]), len(box), 0)
    theta = -theta
    rota_matrix = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])

    new = box_matrix.dot(rota_matrix) + np.repeat(np.array([[x, y]]), len(box), 0)

    x = [new[0][0], new[1][0], new[2][0], new[3][0], new[0][0]]
    y = [new[0][1], new[1][1], new[2][1], new[3][1], new[0][1]]

    return x, y

# %% [markdown]
# ## Vehicle Parameters and Functions for Computing the Vertices of Vehicle

# %%
l_veh_ev = 4.3 # vehicle length, m
w_veh_ev = 1.8 # vehicle width, m
l_veh_sv = 4.3
w_veh_sv = 1.8
p = 8
w_lane  = 4 # lane width
r_round = 210
x_con_c = r_round
y_con_c = -r_round
r_in  = r_round - w_lane + w_veh_ev/2
r_out = r_round - w_veh_ev/2
margin = 0.1
Parameters = {
    'l_veh_ev': l_veh_ev,
    'w_veh_ev': w_veh_ev,
    'l_veh_sv': l_veh_sv,
    'w_veh_sv': w_veh_sv,
    'x_con_c': x_con_c,
    'y_con_c': y_con_c,
    'r_in': r_round - w_lane,
    'r_out': r_round,
    'p': p,}
Check_Safety = Check_Safety(Params = Parameters)

# %% [markdown]
# ## Load Data

# %%
track_parameters = np.load('track_para.npy', allow_pickle = True).item( )
x_track_c_in = track_parameters['x_track_c_in']
y_track_c_in = track_parameters['y_track_c_in']
x_track_1_in = track_parameters['x_track_1_in']
y_track_1_in = track_parameters['y_track_1_in']
x_track_2_in = track_parameters['x_track_2_in']
y_track_2_in = track_parameters['y_track_2_in']
x_track_3_in = track_parameters['x_track_3_in']
y_track_3_in = track_parameters['y_track_3_in']
x_track_4_in = track_parameters['x_track_4_in']
y_track_4_in = track_parameters['y_track_4_in']
x_track_c_out_viz_1 = track_parameters['x_track_c_out_viz_1']
y_track_c_out_viz_1 = track_parameters['y_track_c_out_viz_1']
x_track_c_out_viz_2 = track_parameters['x_track_c_out_viz_2']
y_track_c_out_viz_2 = track_parameters['y_track_c_out_viz_2']
x_track_c_out_viz_3 = track_parameters['x_track_c_out_viz_3']
y_track_c_out_viz_3 = track_parameters['y_track_c_out_viz_3']
x_track_c_out_viz_4 = track_parameters['x_track_c_out_viz_4']
y_track_c_out_viz_4 = track_parameters['y_track_c_out_viz_4']
x_track_1_out_viz_1 = track_parameters['x_track_1_out_viz_1']
y_track_1_out_viz_1 = track_parameters['y_track_1_out_viz_1']
x_track_1_out_viz_2 = track_parameters['x_track_1_out_viz_2']
y_track_1_out_viz_2 = track_parameters['y_track_1_out_viz_2']
x_track_2_out_viz_1 = track_parameters['x_track_2_out_viz_1']
y_track_2_out_viz_1 = track_parameters['y_track_2_out_viz_1']
x_track_2_out_viz_2 = track_parameters['x_track_2_out_viz_2']
y_track_2_out_viz_2 = track_parameters['y_track_2_out_viz_2']
x_track_3_out_viz_1 = track_parameters['x_track_3_out_viz_1']
y_track_3_out_viz_1 = track_parameters['y_track_3_out_viz_1']
x_track_3_out_viz_2 = track_parameters['x_track_3_out_viz_2']
y_track_3_out_viz_2 = track_parameters['y_track_3_out_viz_2']
x_track_4_out_viz_1 = track_parameters['x_track_4_out_viz_1']
y_track_4_out_viz_1 = track_parameters['y_track_4_out_viz_1']
x_track_4_out_viz_2 = track_parameters['x_track_4_out_viz_2']
y_track_4_out_viz_2 = track_parameters['y_track_4_out_viz_2']

# %%
t = np.load('t.npy')

State_SV     = np.load('State_SV.npy')
Control_SV = np.load('Control_SV.npy', allow_pickle=True)
X_SV_Planning = np.load('X_SV_Planning.npy', allow_pickle = True)

State_EV_NRMPC = np.load('State_EV_NRMPC.npy')
State_EV_EARMPC = np.load('State_EV_EARMPC.npy')
State_EV_EANMPC = np.load('State_EV_EANMPC.npy')

Control_EV_NRMPC = np.load('Control_EV_NRMPC.npy')
Control_EV_EARMPC = np.load('Control_EV_EARMPC.npy')
Control_EV_EANMPC = np.load('Control_EV_EANMPC.npy')

J_EV_NRMPC = np.load('J_EV_NRMPC.npy', allow_pickle=True)
J_EV_EARMPC = np.load('J_EV_EARMPC.npy', allow_pickle=True)
J_EV_EANMPC = np.load('J_EV_EANMPC.npy', allow_pickle=True)

X_EV_Planning_NRMPC  = np.load('X_EV_Planning_NRMPC.npy', allow_pickle = True)
X_EV_Planning_EARMPC  = np.load('X_EV_Planning_EARMPC.npy', allow_pickle = True)
X_EV_Planning_EANMPC  = np.load('X_EV_Planning_EANMPC.npy', allow_pickle = True)

Occupancy_SV_NRMPC  = np.load('Occupancy_SV_NRMPC.npy', allow_pickle = True)
Occupancy_SV_EARMPC  = np.load('Occupancy_SV_EARMPC.npy', allow_pickle = True)
Occupancy_SV_EANMPC  = np.load('Occupancy_SV_EANMPC.npy', allow_pickle = True)

Flag_NRMPC   = np.load('Flag_NRMPC.npy', allow_pickle = True)
Flag_EARMPC  = np.load('Flag_EARMPC.npy', allow_pickle = True)
Flag_EANMPC  = np.load('Flag_EANMPC.npy', allow_pickle = True)

# %% [markdown]
# ## Compute the Minimal Distance Between EV and SVs by different planners

# %%
Min_Dis_SV_EARMPC = list( )
Min_Dis_SV_EANMPC = list( )
Min_Dis_SV_NRMPC = list( )

Min_Dis_Road_EARMPC = list( )
Min_Dis_Road_EANMPC = list( )
Min_Dis_Road_NRMPC = list( )

for k in range(len(State_SV[0])):
    Min_Dis_SV_EARMPC.append(Check_Safety.check_vehicle_collision(State_EV_EARMPC[:, k], State_SV[:, k]))
    Min_Dis_SV_EANMPC.append(Check_Safety.check_vehicle_collision(State_EV_EANMPC[:, k], State_SV[:, k]))
    Min_Dis_SV_NRMPC.append(Check_Safety.check_vehicle_collision(State_EV_NRMPC[:, k], State_SV[:, k]))
    
    Min_Dis_Road_EARMPC.append(Check_Safety.check_road_collision(State_EV_EARMPC[:, k]))
    Min_Dis_Road_EANMPC.append(Check_Safety.check_road_collision(State_EV_EANMPC[:, k]))
    Min_Dis_Road_NRMPC.append(Check_Safety.check_road_collision(State_EV_NRMPC[:, k]))

# %% [markdown]
# ## Show the Global Path with Vehicle Shape

# %%
plt.figure(figsize=(4, 4), tight_layout = True)
plt.xlim(-120, 120)
plt.ylim(-120, 50)

for k in range(len(State_SV[0])):
    
    x = State_SV[0, k]
    y = State_SV[1, k]
    box = [(x - l_veh_sv/2, y + w_veh_sv/2), (x + l_veh_sv/2, y + w_veh_sv/2), (x + l_veh_sv/2, y - w_veh_sv/2), (x - l_veh_sv/2, y - w_veh_sv/2)]
    heading = State_SV[2, k]
    x_SV, y_SV = rota_rect(box, heading, x, y)
    
    x = State_EV_EARMPC[0, k]
    y = State_EV_EARMPC[1, k]
    box = [(x - l_veh_ev/2, y + w_veh_ev/2), (x + l_veh_ev/2, y + w_veh_ev/2), (x + l_veh_ev/2, y - w_veh_ev/2), (x - l_veh_ev/2, y - w_veh_ev/2)]
    heading = State_EV_EARMPC[2, k]
    x_EV, y_EV = rota_rect(box, heading, x, y)

    plt.plot(x_SV, y_SV, c = 'r', linewidth = 1)
    plt.plot(x_EV, y_EV, c = 'b', linewidth = 1)
    
plt.plot(x_track_c_in, y_track_c_in, color = 'k')
plt.plot(x_track_1_in, y_track_1_in, color = 'k')
plt.plot(x_track_2_in, y_track_2_in, color = 'k')
plt.plot(x_track_3_in, y_track_3_in, color = 'k')
plt.plot(x_track_4_in, y_track_4_in, color = 'k')
plt.plot(x_track_c_out_viz_1, y_track_c_out_viz_1, color = 'k')
plt.plot(x_track_c_out_viz_2, y_track_c_out_viz_2, color = 'k')
plt.plot(x_track_c_out_viz_3, y_track_c_out_viz_3, color = 'k')
plt.plot(x_track_c_out_viz_4, y_track_c_out_viz_4, color = 'k')
plt.plot(x_track_1_out_viz_1, y_track_1_out_viz_1, color = 'k')
plt.plot(x_track_1_out_viz_2, y_track_1_out_viz_2, color = 'k')
plt.plot(x_track_2_out_viz_1, y_track_2_out_viz_1, color = 'k')
plt.plot(x_track_2_out_viz_2, y_track_2_out_viz_2, color = 'k')
plt.plot(x_track_3_out_viz_1, y_track_3_out_viz_1, color = 'k')
plt.plot(x_track_3_out_viz_2, y_track_3_out_viz_2, color = 'k')
plt.plot(x_track_4_out_viz_1, y_track_4_out_viz_1, color = 'k')
plt.plot(x_track_4_out_viz_2, y_track_4_out_viz_2, color = 'k')
plt.title("Global Path EA-RMPC")   
plt.xlabel("x [m]")
plt.ylabel("y [m]")
# Out:
# Text(0, 0.5, 'y [m]')

# %%
plt.figure(figsize=(4, 4), tight_layout = True)
plt.xlim(-120, 120)
plt.ylim(-120, 50)

for k in range(len(State_SV[0])):
    
    x = State_SV[0, k]
    y = State_SV[1, k]
    box = [(x - l_veh_sv/2, y + w_veh_sv/2), (x + l_veh_sv/2, y + w_veh_sv/2), (x + l_veh_sv/2, y - w_veh_sv/2), (x - l_veh_sv/2, y - w_veh_sv/2)]
    heading = State_SV[2, k]
    x_SV, y_SV = rota_rect(box, heading, x, y)
    
    x = State_EV_EANMPC[0, k]
    y = State_EV_EANMPC[1, k]
    box = [(x - l_veh_ev/2, y + w_veh_ev/2), (x + l_veh_ev/2, y + w_veh_ev/2), (x + l_veh_ev/2, y - w_veh_ev/2), (x - l_veh_ev/2, y - w_veh_ev/2)]
    heading = State_EV_EANMPC[2, k]
    x_EV, y_EV = rota_rect(box, heading, x, y)
    
    plt.plot(x_SV, y_SV, c = 'r', linewidth = 1)
    plt.plot(x_EV, y_EV, c = 'b', linewidth = 1)
    
plt.plot(x_track_c_in, y_track_c_in, color = 'k')
plt.plot(x_track_1_in, y_track_1_in, color = 'k')
plt.plot(x_track_2_in, y_track_2_in, color = 'k')
plt.plot(x_track_3_in, y_track_3_in, color = 'k')
plt.plot(x_track_4_in, y_track_4_in, color = 'k')
plt.plot(x_track_c_out_viz_1, y_track_c_out_viz_1, color = 'k')
plt.plot(x_track_c_out_viz_2, y_track_c_out_viz_2, color = 'k')
plt.plot(x_track_c_out_viz_3, y_track_c_out_viz_3, color = 'k')
plt.plot(x_track_c_out_viz_4, y_track_c_out_viz_4, color = 'k')
plt.plot(x_track_1_out_viz_1, y_track_1_out_viz_1, color = 'k')
plt.plot(x_track_1_out_viz_2, y_track_1_out_viz_2, color = 'k')
plt.plot(x_track_2_out_viz_1, y_track_2_out_viz_1, color = 'k')
plt.plot(x_track_2_out_viz_2, y_track_2_out_viz_2, color = 'k')
plt.plot(x_track_3_out_viz_1, y_track_3_out_viz_1, color = 'k')
plt.plot(x_track_3_out_viz_2, y_track_3_out_viz_2, color = 'k')
plt.plot(x_track_4_out_viz_1, y_track_4_out_viz_1, color = 'k')
plt.plot(x_track_4_out_viz_2, y_track_4_out_viz_2, color = 'k')
plt.title("Global Path of EA-NMPC")   
plt.xlabel("x [m]")
plt.ylabel("y [m]")
# Out:
# Text(0, 0.5, 'y [m]')

# %%
plt.figure(figsize=(4, 4), tight_layout = True)
plt.xlim(-120, 120)
plt.ylim(-120, 50)

for k in range(len(State_SV[0])):
    
    x = State_SV[0, k]
    y = State_SV[1, k]
    box = [(x - l_veh_sv/2, y + w_veh_sv/2), (x + l_veh_sv/2, y + w_veh_sv/2), (x + l_veh_sv/2, y - w_veh_sv/2), (x - l_veh_sv/2, y - w_veh_sv/2)]
    heading = State_SV[2, k]
    x_SV, y_SV = rota_rect(box, heading, x, y)
    
    x = State_EV_NRMPC[0, k]
    y = State_EV_NRMPC[1, k]
    box = [(x - l_veh_ev/2, y + w_veh_ev/2), (x + l_veh_ev/2, y + w_veh_ev/2), (x + l_veh_ev/2, y - w_veh_ev/2), (x - l_veh_ev/2, y - w_veh_ev/2)]
    heading = State_EV_NRMPC[2, k]
    x_EV, y_EV = rota_rect(box, heading, x, y)

    plt.plot(x_SV, y_SV, c = 'r', linewidth = 1)
    plt.plot(x_EV, y_EV, c = 'b', linewidth = 1)
    
plt.plot(x_track_c_in, y_track_c_in, color = 'k')
plt.plot(x_track_1_in, y_track_1_in, color = 'k')
plt.plot(x_track_2_in, y_track_2_in, color = 'k')
plt.plot(x_track_3_in, y_track_3_in, color = 'k')
plt.plot(x_track_4_in, y_track_4_in, color = 'k')
plt.plot(x_track_c_out_viz_1, y_track_c_out_viz_1, color = 'k')
plt.plot(x_track_c_out_viz_2, y_track_c_out_viz_2, color = 'k')
plt.plot(x_track_c_out_viz_3, y_track_c_out_viz_3, color = 'k')
plt.plot(x_track_c_out_viz_4, y_track_c_out_viz_4, color = 'k')
plt.plot(x_track_1_out_viz_1, y_track_1_out_viz_1, color = 'k')
plt.plot(x_track_1_out_viz_2, y_track_1_out_viz_2, color = 'k')
plt.plot(x_track_2_out_viz_1, y_track_2_out_viz_1, color = 'k')
plt.plot(x_track_2_out_viz_2, y_track_2_out_viz_2, color = 'k')
plt.plot(x_track_3_out_viz_1, y_track_3_out_viz_1, color = 'k')
plt.plot(x_track_3_out_viz_2, y_track_3_out_viz_2, color = 'k')
plt.plot(x_track_4_out_viz_1, y_track_4_out_viz_1, color = 'k')
plt.plot(x_track_4_out_viz_2, y_track_4_out_viz_2, color = 'k')
plt.title("Global Path of NRMPC")   
plt.xlabel("x [m]")
plt.ylabel("y [m]")
# Out:
# Text(0, 0.5, 'y [m]')

# %% [markdown]
# ## Show the Minimal Distance between EV and SVs

# %% [markdown]
# ### Minimal Distance w.r.t. SV0

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t, Min_Dis_SV_EARMPC,  color = 'blue', linewidth=1.5, label = 'EA-RMPC')
plt.plot(t, Min_Dis_SV_EANMPC,  color = 'red', linewidth=1.5,  label = 'EA-NMPC')
plt.plot(t, Min_Dis_SV_NRMPC,  color = 'black', linewidth=1.5, label = 'NRMPC')
plt.legend()
plt.xlabel("t [s]")
plt.ylabel("Minimum Distance w.r.t SV[m]")
# Out:
# Text(0, 0.5, 'Minimum Distance w.r.t SV[m]')

# %% [markdown]
# ## Show the Reference Velocity and Actual Velocity

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t, State_EV_EARMPC[3, :],  color = 'blue', linewidth=3, label = 'EA-RMPC')
plt.plot(t, State_EV_EANMPC[3, :],  color = 'red', linewidth=3,  label = 'EA-NMPC')
plt.plot(t, State_EV_NRMPC[3, :],  color = 'black', linewidth=3,  label = 'NRMPC')
plt.legend()
plt.xlabel("t [s]")
plt.ylabel("v [m/s]")
# Out:
# Text(0, 0.5, 'v [m/s]')

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t, State_EV_EARMPC[2, :],  color = 'blue', linewidth=3, label = 'EA-RMPC')
plt.plot(t, State_EV_EANMPC[2, :],  color = 'red', linewidth=3,  label = 'EA-NMPC')
plt.plot(t, State_EV_NRMPC[2, :],  color = 'black', linewidth=3,  label = 'NRMPC')
plt.legend()
plt.xlabel("t [s]")
plt.ylabel("Heading [rad]")
# Out:
# Text(0, 0.5, 'Heading [rad]')

# %% [markdown]
# ## Show Longitudinal Acceleration

# %% [markdown]
# ## Show Heading Angle

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t[0:-1], J_EV_EARMPC,  color = 'blue', linewidth=3, label = 'EA-RMPC')
plt.plot(t[0:-1], J_EV_EANMPC,  color = 'red',  linewidth=3, label = 'EA-NMPC')
plt.plot(t[0:-1], J_EV_NRMPC,  color = 'black',  linewidth=3, label = 'NRMPC')
plt.legend()
plt.xlabel("t [s]")
plt.ylabel('Cost [-]')
# Out:
# Text(0, 0.5, 'Cost [-]')

# %% [markdown]
# ## Show Cost of Optimisation Problems

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t, State_SV[3, :], color = 'red', linewidth=3)
plt.legend("SV Velocity")
plt.xlabel("t [s]")
plt.ylabel('SV Velocity [m/s]')
# Out:
# Text(0, 0.5, 'SV Velocity [m/s]')

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t[:-1], Control_SV[0, :], color = 'red', linewidth=3)
plt.legend("SV Front Tire Angle")
plt.xlabel("t [s]")
plt.ylabel('SV front tire angle [rad]')
# Out:
# Text(0, 0.5, 'SV front tire angle [rad]')

# %%
plt.figure(figsize=(10, 3), tight_layout = True)
plt.plot(t[:-1], Control_SV[1, :], color = 'red',linewidth=3)
plt.legend("SV Acceleration")
plt.xlabel("t [s]")
plt.ylabel('SV acceleration [m/s^2]')
# Out:
# Text(0, 0.5, 'SV acceleration [m/s^2]')

# %% [markdown]
# ## Print the Minimal Distance in the Whole Process

# %%
print('min dis EV SV of EA-RMPC is', np.min(Min_Dis_SV_EARMPC))
print('min dis EV SV of EA-NMPC is', np.min(Min_Dis_SV_EANMPC))
print('min dis EV SV of NRMPC is', np.min(Min_Dis_SV_NRMPC))

print('EA-RMPC: num. of collision with road', np.sum(Min_Dis_Road_EARMPC))
print('EA-NMPC: num. of collision with road', np.sum(Min_Dis_Road_EANMPC))
print('NRMPC: num. of collision with road', np.sum(Min_Dis_Road_NRMPC))

print('EA-RMPC: num. of using backup control', np.sum(Flag_EARMPC))
print('EA-NMPC: num. of using backup control', np.sum(Flag_EANMPC))
print('NRMPC: num. of using backup control', np.sum(Flag_NRMPC))
# Out:
# min dis EV SV of EA-RMPC is 7.423124758330325
# min dis EV SV of EA-NMPC is 5.800612125773624
# min dis EV SV of NRMPC is 23.58692456957324
# EA-RMPC: num. of collision with road 0
# EA-NMPC: num. of collision with road 0
# NRMPC: num. of collision with road 0
# EA-RMPC: num. of using backup control 0
# EA-NMPC: num. of using backup control 0
# NRMPC: num. of using backup control 0

# %%
N = 10
for i in range(len(Occupancy_SV_EARMPC)):
    Occupancy_SV_EARMPC_i   = Occupancy_SV_EARMPC[i]
    Occupancy_SV_NRMPC_i    = Occupancy_SV_NRMPC[i]
    for j in range(N):
        Occupancy_SV_EARMPC_ij = Occupancy_SV_EARMPC_i[j]
        Occupancy_SV_EARMPC_i[j] = Occupancy_SV_EARMPC_ij.V
        
        Occupancy_SV_NRMPC_ij = Occupancy_SV_NRMPC_i[j]
        Occupancy_SV_NRMPC_i[j] = Occupancy_SV_NRMPC_ij.V
        
    Occupancy_SV_EARMPC[i]  = Occupancy_SV_EARMPC_i
    Occupancy_SV_NRMPC[i]  = Occupancy_SV_NRMPC_i

# %%
file_name = 'Occupancy_SV_EARMPC.mat'
savemat(file_name, {'Occupancy_SV_EARMPC':Occupancy_SV_EARMPC})
file_name = 'Occupancy_SV_NRMPC.mat'
savemat(file_name, {'Occupancy_SV_NRMPC':Occupancy_SV_NRMPC})
file_name = 'Occupancy_SV_EANMPC.mat'
savemat(file_name, {'Occupancy_SV_EANMPC':Occupancy_SV_EANMPC})

file_name = 'Min_Dis_SV_EARMPC.mat'
savemat(file_name, {'Min_Dis_SV_EARMPC':Min_Dis_SV_EARMPC})
file_name = 'Min_Dis_SV_EANMPC.mat'
savemat(file_name, {'Min_Dis_SV_EANMPC':Min_Dis_SV_EANMPC})
file_name = 'Min_Dis_SV_NRMPC.mat'
savemat(file_name, {'Min_Dis_SV_NRMPC':Min_Dis_SV_NRMPC})

file_names = [
    'track_para.npy',
    't.npy',
    'State_SV.npy',
    'Control_SV.npy',
    'X_SV_Planning.npy',
    'State_EV_EARMPC.npy',
    'State_EV_NRMPC.npy',
    'State_EV_EANMPC.npy',
    'Control_EV_EARMPC.npy',
    'Control_EV_NRMPC.npy',
    'Control_EV_EANMPC.npy',
    'J_EV_EARMPC.npy',
    'J_EV_NRMPC.npy',
    'J_EV_EANMPC.npy',
    'X_EV_Planning_EARMPC.npy',
    'X_EV_Planning_NRMPC.npy',
    'X_EV_Planning_EANMPC.npy',]

for file_name in file_names:
    variable_name = file_name.split('.')[0]
    data = np.load(file_name, allow_pickle=True)
    savemat(f"{variable_name}.mat", {variable_name: data})
